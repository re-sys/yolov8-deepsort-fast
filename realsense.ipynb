# %%
import pyrealsense2 as rs
import numpy as np
import cv2
import os
 
# Configure depth and rgb and infrared streams
pipeline = rs.pipeline()
config = rs.config()
config.enable_stream(rs.stream.depth, 1024, 768, rs.format.z16, 30)
# config.enable_stream(rs.stream.infrared, 1024, 768, rs.format.y8, 30)
config.enable_stream(rs.stream.color, 1280, 720, rs.format.bgr8, 30)
profile = pipeline.start(config)

# %%
# Getting the depth sensor's depth scale (see rs-align example for explanation)
depth_sensor = profile.get_device().first_depth_sensor()
depth_scale = depth_sensor.get_depth_scale()
print("Depth Scale is: " , depth_scale)

# We will be removing the background of objects more than
#  clipping_distance_in_meters meters away
clipping_distance_in_meters = 1 #1 meter
clipping_distance = clipping_distance_in_meters / depth_scale

# Create an align object
# rs.align allows us to perform alignment of depth frames to others frames
# The "align_to" is the stream type to which we plan to align depth frames.
align_to = rs.stream.color
align = rs.align(align_to)

# Streaming loop
try:
    while True:
        # Get frameset of color and depth
        frames = pipeline.wait_for_frames()
        # frames.get_depth_frame() is a 640x360 depth image

        # Align the depth frame to color frame
        aligned_frames = align.process(frames)

        # Get aligned frames
        aligned_depth_frame = aligned_frames.get_depth_frame() # aligned_depth_frame is a 640x480 depth image
        color_frame = aligned_frames.get_color_frame()

        # Validate that both frames are valid
        if not aligned_depth_frame or not color_frame:
            continue

        depth_image = np.asanyarray(aligned_depth_frame.get_data())
        color_image = np.asanyarray(color_frame.get_data())

        # Remove background - Set pixels further than clipping_distance to grey
        grey_color = 153
        depth_image_3d = np.dstack((depth_image,depth_image,depth_image)) #depth image is 1 channel, color is 3 channels
        bg_removed = np.where((depth_image_3d > clipping_distance) | (depth_image_3d <= 0), grey_color, color_image)

        # Render images
        depth_colormap = cv2.applyColorMap(cv2.convertScaleAbs(depth_image, alpha=0.03), cv2.COLORMAP_JET)
        images = np.hstack((bg_removed, depth_colormap))
        cv2.namedWindow('Align Example', cv2.WINDOW_AUTOSIZE)
        cv2.imshow('Align Example', images)
        key = cv2.waitKey(1)
        # Press esc or 'q' to close the image window
        if key & 0xFF == ord('q') or key == 27:
            cv2.destroyAllWindows()
            break
finally:
    pipeline.stop()
# Out:
# Depth Scale is:  0.0002500000118743628

# %%
alignIt = rs.align(rs.stream.color) # rs.stream.depth
aligned_frame = alignIt.process(frame)
# i prefer frame = alignIt.process(frame)

# %%
#!/usr/bin/env python3
import pyrealsense2 as rs
import numpy as np
import cv2
# import rospy
# from sensor_msgs.msg import Image
# from cv_bridge import CvBridge, CvBridgeError
# import message_filters

# import tf
# import tf.transformations as transformations
# from geometry_msgs.msg import PoseStamped  # 导入PoseStamped消息类型

from ultralytics import YOLO
import time
import openvino as ov
import torch
# import time

import deep_sort.deep_sort.deep_sort as ds
# import tf.transformations
# from FSM import State

# bridge = CvBridge()
#内参
fx = 897.6827392578125
fy = 898.0628051757812
cx = 649.2904052734375
cy = 376.3505859375
y_mouse,x_mouse = 100,100

# parent_dir = "/home/wu/Lab/yolov8-deepsort-fast/"
tracker = ds.DeepSort("/home/wu/catkin_ws/src/my_pkg/cv_pkg/scripts/ckpt.t8")
Rot = np.array([[0,0,1],[1,0,0],[0,-1,0]])
# tran = np.array([0,0,0.521])
# def mouse_callback(event, x, y, flags, param):
#     global x_mouse, y_mouse
#     if event == cv2.EVENT_LBUTTONDOWN:
#         x_mouse = x
#         y_mouse = y
#         print(f"Mouse clicked at: x={x}, y={y}")

def extract_detections(results, detect_class):
    """
    从模型结果中提取和处理检测信息。
    - results: YoloV8模型预测结果，包含检测到的物体的位置、类别和置信度等信息。
    - detect_class: 需要提取的目标类别的索引。
    参考: https://docs.ultralytics.com/modes/predict/#working-with-results
    """
    
    # 初始化一个空的二维numpy数组，用于存放检测到的目标的位置信息
    # 如果视频中没有需要提取的目标类别，如果不初始化，会导致tracker报错
    detections = np.empty((0, 4)) 
    
    confarray = [] # 初始化一个空列表，用于存放检测到的目标的置信度。
    
    # 遍历检测结果
    # 参考：https://docs.ultralytics.com/modes/predict/#working-with-results
    for r in results:
        for box in r.boxes:
            # 如果检测到的目标类别与指定的目标类别相匹配，提取目标的位置信息和置信度
            if box.cls[0].int() == detect_class:
                x1, y1, x2, y2 = box.xywh[0].int().tolist() # 提取目标的位置信息，并从tensor转换为整数列表。
                conf = round(box.conf[0].item(), 2) # 提取目标的置信度，从tensor中取出浮点数结果，并四舍五入到小数点后两位。
                detections = np.vstack((detections, np.array([x1, y1, x2, y2]))) # 将目标的位置信息添加到detections数组中。
                confarray.append(conf) # 将目标的置信度添加到confarray列表中。
    return detections, confarray # 返回提取出的位置信息和置信度。

def image_callback(color_image,aligned_depth_image):
    global x_mouse, y_mouse
    # current_state = rospy.get_param("current_state", "WAITING")  # 默认值为 "WAITING"

    # 检查状态是否为 TRACKING
    # if current_state != State.TRACKING:
    #     return  # 如果不是 TRACKING，则直接返回，不处理图像
    # try:
    #     cv_color_image = bridge.imgmsg_to_cv2(color_image, "bgr8")
    #     # print(depth_image)
    #     # cv_depth_image = bridge.imgmsg_to_cv2(depth_image, "32FC1")
    #     cv_aligned_depth_image = bridge.imgmsg_to_cv2(aligned_depth_image, "32FC1")
    # except CvBridgeError as e:
    #     print(e)
    #     return
    cv_color_image = color_image
    cv_aligned_depth_image = aligned_depth_image
    results = model.predict(cv_color_image,imgsz=480,half=True)
    detections, confarray = extract_detections(results, 0)
    resultsTracker = tracker.update(detections, confarray, cv_color_image)
    for x1, y1, x2, y2, Id in resultsTracker:
        x1, y1, x2, y2 = map(int, [x1, y1, x2, y2])  # Convert position to integers.  
        # print(f"Id: {Id}, x1: {x1}, y1: {y1}, x2: {x2}, y2: {y2}")
        if Id == 1:
            x_mouse = (x1 + x2) // 2
            y_mouse = (y1 + y2) // 2
            print("detedted")
            
        cv2.rectangle(cv_color_image, (x1, y1), (x2, y2), (255, 0, 255), 3)
        cv2.putText(cv_color_image, "LID-" + str(int(Id)), (max(-10, x1), max(40, y1)), fontScale=1, fontFace=cv2.FONT_HERSHEY_SIMPLEX, color=(255, 255, 255), thickness=2)
    
    
    
    
    
    if 0 <= x_mouse < cv_aligned_depth_image.shape[1] and 0 <= y_mouse < cv_aligned_depth_image.shape[0]:
        depth = cv_aligned_depth_image[y_mouse, x_mouse] / 1000.0
        cam_x = (x_mouse - cx) * depth / fx
        cam_y = (y_mouse - cy) * depth / fy
        cam_z = depth
        # print("Aligned Depth at center pixel: ", depth)
        x,y,z = np.dot(Rot, np.array([cam_x,cam_y,cam_z]))
        yaw = np.arctan2(y,x)
        # quaternion = tf.transformations.quaternion_from_euler(0, 0, yaw)
        print(x,y,z)
        cv2.circle(cv_color_image, (x_mouse, y_mouse), 5, (0, 0, 255), -1)
        cv2.putText(cv_color_image, f"x={x:.2f}, y={y:.2f}, z={z:.2f}", (x_mouse, y_mouse), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 2)
        cv2.imshow("cv_color_image", cv_color_image)
        cv2.waitKey(1)    
    # 创建 PoseStamped 消息并发布
        
           

    
    


if __name__ == '__main__':
    # rospy.init_node('get_image', anonymous=True)
    import pyrealsense2 as rs
    import numpy as np
    import cv2
    import os
    
    # Configure depth and rgb and infrared streams
    pipeline = rs.pipeline()
    config = rs.config()
    config.enable_stream(rs.stream.depth, 1024, 768, rs.format.z16, 30)
    # config.enable_stream(rs.stream.infrared, 1024, 768, rs.format.y8, 30)
    config.enable_stream(rs.stream.color, 1280, 720, rs.format.bgr8, 30)
    profile = pipeline.start(config)
    # Getting the depth sensor's depth scale (see rs-align example for explanation)
    depth_sensor = profile.get_device().first_depth_sensor()
    depth_scale = depth_sensor.get_depth_scale()
    print("Depth Scale is: " , depth_scale)

    # We will be removing the background of objects more than
    #  clipping_distance_in_meters meters away
    clipping_distance_in_meters = 1 #1 meter
    clipping_distance = clipping_distance_in_meters / depth_scale

    # 创建订阅对象
    # color_sub = message_filters.Subscriber('/camera/color/image_raw', Image)
    # # depth_sub = message_filters.Subscriber('/camera/depth/image_rect_raw', Image)
    # align_sub = message_filters.Subscriber('/camera/aligned_depth_to_color/image_raw', Image)
    
    # pose_pub = rospy.Publisher('goal_pose', PoseStamped, queue_size=1)

    # 创建模型对象
    model = YOLO("/home/wu/catkin_ws/src/my_pkg/cv_pkg/scripts/yolov8n_ncnn_model")
    align_to = rs.stream.color
    align = rs.align(align_to)

# Streaming loop
    try:
        while True:
            # Get frameset of color and depth
            frames = pipeline.wait_for_frames()
            # frames.get_depth_frame() is a 640x360 depth image

            # Align the depth frame to color frame
            aligned_frames = align.process(frames)

            # Get aligned frames
            aligned_depth_frame = aligned_frames.get_depth_frame() # aligned_depth_frame is a 640x480 depth image
            color_frame = aligned_frames.get_color_frame()

            # Validate that both frames are valid
            if not aligned_depth_frame or not color_frame:
                continue

            depth_image = np.asanyarray(aligned_depth_frame.get_data())
            color_image = np.asanyarray(color_frame.get_data())
            image_callback(color_image,depth_image)
            # # Remove background - Set pixels further than clipping_distance to grey
            # grey_color = 153
            # depth_image_3d = np.dstack((depth_image,depth_image,depth_image)) #depth image is 1 channel, color is 3 channels
            # bg_removed = np.where((depth_image_3d > clipping_distance) | (depth_image_3d <= 0), grey_color, color_image)

            # # Render images
            # depth_colormap = cv2.applyColorMap(cv2.convertScaleAbs(depth_image, alpha=0.03), cv2.COLORMAP_JET)
            # images = np.hstack((bg_removed, depth_colormap))
            # cv2.namedWindow('Align Example', cv2.WINDOW_AUTOSIZE)
            # cv2.imshow('Align Example', images)
            # key = cv2.waitKey(1)
            # # Press esc or 'q' to close the image window
            # if key & 0xFF == ord('q') or key == 27:
            #     cv2.destroyAllWindows()
            #     break
    finally:
        pipeline.stop()
    # 创建时间同步对象
    # ts = message_filters.TimeSynchronizer([color_sub,align_sub], 10)  # 10是缓冲区大小
    # ts.registerCallback(image_callback)

    # rospy.spin()
# Out:
# Depth Scale is:  0.0002500000118743628
# WARNING ⚠️ Unable to automatically guess model task, assuming 'task=detect'. Explicitly define task for your model, i.e. 'task=detect', 'segment', 'classify','pose' or 'obb'.
# Loading /home/wu/catkin_ws/src/my_pkg/cv_pkg/scripts/yolov8n_ncnn_model for NCNN inference...
#
# 0: 480x480 (no detections), 73.8ms
# Speed: 2.9ms preprocess, 73.8ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 480)
# 7.794 -4.76913416229966 2.3983583936262547
#
# 0: 480x480 (no detections), 80.3ms
# Speed: 2.2ms preprocess, 80.3ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 480)
# 7.834 -4.793610088203173 2.4106671357028584
#
# 0: 480x480 (no detections), 72.5ms
# Speed: 2.3ms preprocess, 72.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 480)
# 7.718 -4.722629903082984 2.3749717836807074
#
# 0: 480x480 (no detections), 79.8ms
# Speed: 2.5ms preprocess, 79.8ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 480)
# 7.743 -4.737927356772681 2.382664747478585
#
# 0: 480x480 (no detections), 73.7ms
# Speed: 2.8ms preprocess, 73.7ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 480)
# 7.739 -4.735479764182329 2.3814338732709244
#
# 0: 480x480 (no detections), 81.2ms
# Speed: 2.7ms preprocess, 81.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 480)
# 7.81 -4.778924532661065 2.4032818904568964
#
# 0: 480x480 (no detections), 102.3ms
# Speed: 3.7ms preprocess, 102.3ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 480)
# 7.789 -4.766074671561721 2.396819800866679
#
# 0: 480x480 (no detections), 81.7ms
# Speed: 2.1ms preprocess, 81.7ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 480)
# 7.737 -4.734255967887154 2.380818436167094
#
# 0: 480x480 (no detections), 87.2ms
# Speed: 1.9ms preprocess, 87.2ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 480)
# 7.761 -4.748941523429261 2.388203681413057
#
# 0: 480x480 (no detections), 81.0ms
# Speed: 1.6ms preprocess, 81.0ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 480)
# 7.792 -4.767910366004484 2.3977429565224244
#
# 0: 480x480 (no detections), 79.3ms
# Speed: 2.3ms preprocess, 79.3ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 480)
# 7.847 -4.801564764121816 2.414667476877755
#
# 0: 480x480 (no detections), 82.2ms
# Speed: 2.4ms preprocess, 82.2ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 480)
# 7.782 -4.761791384528606 2.394665771003274
#
# 0: 480x480 (no detections), 75.9ms
# Speed: 2.4ms preprocess, 75.9ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 480)
# 7.732 -4.731196477149213 2.379279843407519
#
# 0: 480x480 (no detections), 88.8ms
# Speed: 2.5ms preprocess, 88.8ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 480)
# 7.742 -4.737315458625093 2.38235702892667
#
# 0: 480x480 (no detections), 81.6ms
# Speed: 1.7ms preprocess, 81.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 480)
# 7.751 -4.742822541953383 2.3851264958939056
#
# 0: 480x480 (no detections), 90.8ms
# Speed: 2.2ms preprocess, 90.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 480)
# 7.764 -4.750777217872025 2.389126837068802
#
# 0: 480x480 (no detections), 105.3ms
# Speed: 3.0ms preprocess, 105.3ms inference, 6.2ms postprocess per image at shape (1, 3, 480, 480)
# 7.785 -4.7636270789713695 2.3955889266590193
#
# 0: 480x480 (no detections), 94.9ms
# Speed: 3.2ms preprocess, 94.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 480)
# 7.759 -4.747717727134086 2.3875882443092267
#
# 0: 480x480 (no detections), 90.1ms
# Speed: 1.7ms preprocess, 90.1ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 480)
# 7.766 -4.752001014167201 2.389742274172632
#
# 0: 480x480 (no detections), 80.1ms
# Speed: 2.8ms preprocess, 80.1ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 480)
# 7.755 -4.745270134543735 2.386357370101566
#
# 0: 480x480 (no detections), 85.0ms
# Speed: 2.3ms preprocess, 85.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 480)
# 7.815 -4.781984023399005 2.4048204832164717
#
# 0: 480x480 (no detections), 80.1ms
# Speed: 2.7ms preprocess, 80.1ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 480)
# 7.737 -4.734255967887154 2.380818436167094
#
# 0: 480x480 (no detections), 82.7ms
# Speed: 2.2ms preprocess, 82.7ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 480)
# 7.791 -4.7672984678568975 2.3974352379705097
#
# 0: 480x480 (no detections), 84.6ms
# Speed: 2.4ms preprocess, 84.6ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 480)
# 7.75 -4.742210643805795 2.3848187773419904
#
# 0: 480x480 (no detections), 80.8ms
# Speed: 2.4ms preprocess, 80.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 480)
# 7.826 -4.788714903022471 2.408205387287538
#
# 0: 480x480 (no detections), 75.3ms
# Speed: 2.9ms preprocess, 75.3ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 480)
# 7.794 -4.76913416229966 2.3983583936262547
#
# 0: 480x480 (no detections), 85.6ms
# Speed: 2.2ms preprocess, 85.6ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 480)
# 7.795 -4.769746060447248 2.39866611217817
#
# 0: 480x480 (no detections), 76.7ms
# Speed: 2.8ms preprocess, 76.7ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 480)
# 7.78 -4.76056758823343 2.3940503338994437
#
# 0: 480x480 (no detections), 82.5ms
# Speed: 2.4ms preprocess, 82.5ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 480)
# 7.779 -4.759955690085842 2.393742615347528
#
# 0: 480x480 (no detections), 76.4ms
# Speed: 2.6ms preprocess, 76.4ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 480)
# 7.826 -4.788714903022471 2.408205387287538
#
# 0: 480x480 (no detections), 77.1ms
# Speed: 2.7ms preprocess, 77.1ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 480)
# 7.814 -4.781372125251417 2.404512764664557
#
# 0: 480x480 (no detections), 81.0ms
# Speed: 2.8ms preprocess, 81.0ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 480)
# 7.782 -4.761791384528606 2.394665771003274
#
# 0: 480x480 (no detections), 75.6ms
# Speed: 2.6ms preprocess, 75.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 480)
# 7.761 -4.748941523429261 2.388203681413057
#
# 0: 480x480 (no detections), 77.5ms
# Speed: 3.2ms preprocess, 77.5ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 480)
# 7.777 -4.758731893790666 2.3931271782436982
#
# 0: 480x480 (no detections), 78.3ms
# Speed: 1.7ms preprocess, 78.3ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 480)
# 7.778 -4.759343791938255 2.393434896795613
#
# 0: 480x480 (no detections), 77.8ms
# Speed: 2.4ms preprocess, 77.8ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 480)
# 7.812 -4.780148328956241 2.4038973275607267
#
# 0: 480x480 (no detections), 79.6ms
# Speed: 2.5ms preprocess, 79.6ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 480)
# 7.773 -4.756284301200315 2.3918963040360377
#
# 0: 480x480 (no detections), 78.7ms
# Speed: 2.0ms preprocess, 78.7ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 480)
# 7.789 -4.766074671561721 2.396819800866679
#
# 0: 480x480 (no detections), 79.9ms
# Speed: 3.1ms preprocess, 79.9ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 480)
# 7.749 -4.741598745658207 2.3845110587900757
#
# 0: 480x480 (no detections), 147.7ms
# Speed: 3.0ms preprocess, 147.7ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 480)
# 7.779 -4.759955690085842 2.393742615347528
#
# 0: 480x480 (no detections), 91.7ms
# Speed: 2.7ms preprocess, 91.7ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 480)
# 7.817 -4.783207819694181 2.405435920320302
#
# 0: 480x480 (no detections), 76.1ms
# Speed: 2.3ms preprocess, 76.1ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 480)
# 7.757 -4.746493930838909 2.3869728072053964
#
# 0: 480x480 (no detections), 74.3ms
# Speed: 2.9ms preprocess, 74.3ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 480)
# 7.828 -4.789938699317647 2.408820824391368
#
# 0: 480x480 (no detections), 73.9ms
# Speed: 1.9ms preprocess, 73.9ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 480)
# 7.79 -4.766686569709308 2.397127519418594
#
# 0: 480x480 (no detections), 83.4ms
# Speed: 6.9ms preprocess, 83.4ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 480)
# 7.753 -4.744046338248559 2.385741932997736
#
# 0: 480x480 (no detections), 75.9ms
# Speed: 2.3ms preprocess, 75.9ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 480)
# 7.779 -4.759955690085842 2.393742615347528
#
# 0: 480x480 (no detections), 84.8ms
# Speed: 2.9ms preprocess, 84.8ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 480)
# 7.745 -4.739151153067856 2.383280184582415
#
# 0: 480x480 (no detections), 79.0ms
# Speed: 3.3ms preprocess, 79.0ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 480)
# 7.751 -4.742822541953383 2.3851264958939056
#
# 0: 480x480 (no detections), 79.2ms
# Speed: 2.1ms preprocess, 79.2ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 480)
# 7.789 -4.766074671561721 2.396819800866679
#
# 0: 480x480 (no detections), 77.8ms
# Speed: 3.2ms preprocess, 77.8ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 480)
# 7.764 -4.750777217872025 2.389126837068802
#
# 0: 480x480 1 person, 78.9ms
# Speed: 2.2ms preprocess, 78.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 480)
# 7.781 -4.761179486381018 2.3943580524513584
#
# 0: 480x480 1 person, 78.2ms
# Speed: 2.4ms preprocess, 78.2ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 480)
# 7.816 -4.782595921546593 2.405128201768387
#
# 0: 480x480 1 person, 81.2ms
# Speed: 1.9ms preprocess, 81.2ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 480)
# 7.793 -4.768522264152072 2.3980506750743396
#
# 0: 480x480 1 person, 81.4ms
# Speed: 3.8ms preprocess, 81.4ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 480)
# detedted
# 2.253 0.3506424966789356 -0.6162688474493541
#
# 0: 480x480 1 person, 80.4ms
# Speed: 2.5ms preprocess, 80.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 480)
# detedted
# 2.223 0.3038750965654979 -0.5907355748433399
#
# 0: 480x480 1 person, 82.7ms
# Speed: 3.1ms preprocess, 82.7ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 480)
# detedted
# 2.153 0.2367448410804892 -0.555352237730124
#
# 0: 480x480 1 person, 82.9ms
# Speed: 1.8ms preprocess, 82.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 480)
# detedted
# 2.103 0.17736475343348904 -0.5284048231799934
#
# 0: 480x480 1 person, 83.4ms
# Speed: 1.9ms preprocess, 83.4ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 480)
# detedted
# 2.067 0.1282766474879644 -0.5078512730275215
#
# 0: 480x480 1 person, 82.1ms
# Speed: 3.4ms preprocess, 82.1ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 480)
# detedted
# 2.043 0.07444244954694958 -0.49512990669138446
#
# 0: 480x480 1 person, 77.8ms
# Speed: 2.4ms preprocess, 77.8ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 480)
# detedted
# 2.037 0.03791700894923004 -0.4891393496241401
#
# 0: 480x480 1 person, 87.4ms
# Speed: 2.8ms preprocess, 87.4ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 480)
# detedted
# 2.032 0.01745148458276838 -0.4879387130271246
#
# 0: 480x480 1 person, 103.6ms
# Speed: 2.7ms preprocess, 103.6ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 480)
# detedted
# 2.032 0.0016062428532012695 -0.49246400900484244
#
# 0: 480x480 1 person, 84.0ms
# Speed: 2.0ms preprocess, 84.0ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 480)
# detedted
# 2.026 -0.018710798759338176 -0.49100988299400133
#
# 0: 480x480 1 person, 81.6ms
# Speed: 2.4ms preprocess, 81.6ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 480)
# detedted
# 2.012 -0.0320294622506924 -0.4853765444705506
#
# 0: 480x480 1 person, 77.1ms
# Speed: 3.2ms preprocess, 77.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 480)
# detedted
# 2.01 -0.03647582065205049 -0.4848940628160072
#
# 0: 480x480 1 person, 79.4ms
# Speed: 2.3ms preprocess, 79.4ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 480)
# detedted
# 2.003 -0.038580090992201735 -0.4832053770251058
#
# 0: 480x480 1 person, 77.6ms
# Speed: 2.8ms preprocess, 77.6ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 480)
# detedted
# 1.996 -0.040668765621989234 -0.48151669123420426
#
# 0: 480x480 1 person, 78.6ms
# Speed: 2.6ms preprocess, 78.6ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 480)
# detedted
# 1.994 -0.040628015355834934 -0.481034209579661
#
# 0: 480x480 1 person, 81.3ms
# Speed: 3.8ms preprocess, 81.3ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 480)
# detedted
# 1.996 -0.036221760209697904 -0.4792941295286125
#
# 0: 480x480 1 person, 96.2ms
# Speed: 2.9ms preprocess, 96.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 480)
# detedted
# 1.994 -0.031742916365745846 -0.47881387488980626
#
# 0: 480x480 1 person, 75.9ms
# Speed: 1.9ms preprocess, 75.9ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 480)
# detedted
# 1.981 -0.02932917354348089 -0.4756922197375658
#
# 0: 480x480 1 person, 77.3ms
# Speed: 1.6ms preprocess, 77.3ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 480)
# detedted
# 1.978 -0.029284757833924886 -0.4705668006514402
#
# 0: 480x480 1 person, 79.3ms
# Speed: 2.4ms preprocess, 79.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 480)
# detedted
# 1.967 -0.024739505620006593 -0.46575962733370935
#
# 0: 480x480 1 person, 81.4ms
# Speed: 2.6ms preprocess, 81.4ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 480)
# detedted
# 1.966 -0.0159665950349322 -0.46333368406837605
#
# 0: 480x480 1 person, 81.4ms
# Speed: 2.3ms preprocess, 81.4ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 480)
# detedted
# 1.963 -0.005008524008688277 -0.46262666420458914
#
# 0: 480x480 1 person, 80.5ms
# Speed: 2.1ms preprocess, 80.5ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 480)
# detedted
# 1.961 0.00591914607067323 -0.4599717286985381
#
# 0: 480x480 1 person, 80.5ms
# Speed: 2.5ms preprocess, 80.5ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 480)
# detedted
# 0.0 0.0 0.0
#
# 0: 480x480 1 person, 81.8ms
# Speed: 2.9ms preprocess, 81.8ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 480)
# detedted
# 0.0 0.0 0.0
#
# 0: 480x480 1 person, 85.6ms
# Speed: 3.0ms preprocess, 85.6ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 480)
# detedted
# 0.0 0.0 0.0
#
# 0: 480x480 1 person, 72.6ms
# Speed: 2.4ms preprocess, 72.6ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 480)
# detedted
# 0.0 0.0 0.0
#
# 0: 480x480 1 person, 78.3ms
# Speed: 2.3ms preprocess, 78.3ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 480)
# detedted
# 0.0 0.0 0.0
#
# 0: 480x480 1 person, 83.0ms
# Speed: 1.7ms preprocess, 83.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 480)
# detedted
# 0.0 0.0 0.0
#
# 0: 480x480 1 person, 76.1ms
# Speed: 3.0ms preprocess, 76.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 480)
# detedted
# 0.0 0.0 0.0
#
# 0: 480x480 1 person, 90.5ms
# Speed: 4.3ms preprocess, 90.5ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 480)
# detedted
# 0.0 0.0 0.0
#
# 0: 480x480 1 person, 79.2ms
# Speed: 2.0ms preprocess, 79.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 480)
# detedted
# 0.0 0.0 0.0
#
# 0: 480x480 1 person, 77.1ms
# Speed: 1.9ms preprocess, 77.1ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 480)
# detedted
# 0.0 0.0 0.0
#
# 0: 480x480 1 person, 76.0ms
# Speed: 1.8ms preprocess, 76.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 480)
# detedted
# 0.0 0.0 0.0
#
# 0: 480x480 1 person, 84.7ms
# Speed: 3.8ms preprocess, 84.7ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 480)
# detedted
# 0.0 0.0 0.0
#
# 0: 480x480 1 person, 82.3ms
# Speed: 2.7ms preprocess, 82.3ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 480)
# detedted
# 0.0 0.0 0.0
#
# 0: 480x480 1 person, 77.6ms
# Speed: 3.4ms preprocess, 77.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 480)
# detedted
# 0.0 0.0 0.0
#
# 0: 480x480 1 person, 81.7ms
# Speed: 2.4ms preprocess, 81.7ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 480)
# detedted
# 0.0 0.0 0.0
#
# 0: 480x480 1 person, 77.1ms
# Speed: 2.5ms preprocess, 77.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 480)
# detedted
# 0.0 0.0 0.0
#
# 0: 480x480 1 person, 78.0ms
# Speed: 2.9ms preprocess, 78.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 480)
# detedted
# 0.0 0.0 0.0
#
# 0: 480x480 1 person, 82.3ms
# Speed: 2.8ms preprocess, 82.3ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 480)
# detedted
# 0.0 0.0 0.0
#
# 0: 480x480 1 person, 85.7ms
# Speed: 4.9ms preprocess, 85.7ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 480)
# detedted
# 0.0 0.0 0.0
#
# 0: 480x480 1 person, 89.4ms
# Speed: 2.4ms preprocess, 89.4ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 480)
# detedted
# 0.0 0.0 0.0
#
# 0: 480x480 1 person, 79.7ms
# Speed: 2.4ms preprocess, 79.7ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 480)
# detedted
# 0.0 0.0 0.0
#
# 0: 480x480 1 person, 74.0ms
# Speed: 2.3ms preprocess, 74.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 480)
# detedted
# 0.0 0.0 0.0
#
# 0: 480x480 1 person, 80.0ms
# Speed: 1.6ms preprocess, 80.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 480)
# detedted
# 0.0 0.0 0.0
#
# 0: 480x480 1 person, 79.7ms
# Speed: 4.0ms preprocess, 79.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 480)
# detedted
# 0.0 0.0 0.0
#
# 0: 480x480 1 person, 82.2ms
# Speed: 3.2ms preprocess, 82.2ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 480)
# detedted
# 0.0 0.0 0.0
#
# 0: 480x480 1 person, 81.4ms
# Speed: 2.5ms preprocess, 81.4ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 480)
# detedted
# 1.983 0.3351296768739282 -0.5159180242357869
#
# 0: 480x480 (no detections), 80.0ms
# Speed: 1.8ms preprocess, 80.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 480)
# 6.914 1.1684753332861015 -1.7988185676077815
#
# 0: 480x480 (no detections), 75.4ms
# Speed: 2.5ms preprocess, 75.4ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 480)
# 6.913 1.1683063319361904 -1.798558397146745
#
# 0: 480x480 (no detections), 77.0ms
# Speed: 3.2ms preprocess, 77.0ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 480)
# 6.928 1.1708413521848584 -1.8024609540622956
#
# 0: 480x480 (no detections), 136.1ms
# Speed: 13.9ms preprocess, 136.1ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 480)
# 6.925 1.170334348135125 -1.801680442679185
#
# 0: 480x480 (no detections), 80.0ms
# Speed: 2.7ms preprocess, 80.0ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 480)
# 6.923 1.1699963454353026 -1.8011601017571117
#
# 0: 480x480 (no detections), 76.9ms
# Speed: 2.5ms preprocess, 76.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 480)
# 6.912 1.1681373305862792 -1.7982982266857082
#
# 0: 480x480 (no detections), 83.7ms
# Speed: 2.3ms preprocess, 83.7ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 480)
# 6.903 1.1666163184370781 -1.7959566925363777
#
# 0: 480x480 (no detections), 79.7ms
# Speed: 2.2ms preprocess, 79.7ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 480)
# 6.907 1.1672923238367232 -1.7969973743805245
#
# 0: 480x480 (no detections), 82.0ms
# Speed: 2.3ms preprocess, 82.0ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 480)
# 6.917 1.1689823373358352 -1.7995990789908916
#
# 0: 480x480 (no detections), 82.9ms
# Speed: 2.6ms preprocess, 82.9ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 480)
# 6.908 1.1674613251866346 -1.7972575448415615
#
# 0: 480x480 (no detections), 73.9ms
# Speed: 2.4ms preprocess, 73.9ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 480)
# 6.934 1.171855360284326 -1.8040219768285155
#
# 0: 480x480 (no detections), 81.8ms
# Speed: 2.6ms preprocess, 81.8ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 480)
# 6.913 1.1683063319361904 -1.798558397146745
#
# 0: 480x480 (no detections), 77.4ms
# Speed: 2.3ms preprocess, 77.4ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 480)
# 6.919 1.1693203400356578 -1.800119419912965
#
# 0: 480x480 (no detections), 76.9ms
# Speed: 3.6ms preprocess, 76.9ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 480)
# 6.906 1.167123322486812 -1.7967372039194878
#
# 0: 480x480 (no detections), 76.1ms
# Speed: 2.5ms preprocess, 76.1ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 480)
# 6.92 1.169489341385569 -1.8003795903740016
#
# 0: 480x480 (no detections), 74.7ms
# Speed: 2.0ms preprocess, 74.7ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 480)
# 6.915 1.1686443346360127 -1.7990787380688182
#
# 0: 480x480 (no detections), 75.9ms
# Speed: 2.3ms preprocess, 75.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 480)
# 6.914 1.1684753332861015 -1.7988185676077815
#
# 0: 480x480 (no detections), 75.9ms
# Speed: 2.6ms preprocess, 75.9ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 480)
# 6.933 1.1716863589344146 -1.803761806367479
#
# 0: 480x480 (no detections), 75.8ms
# Speed: 2.4ms preprocess, 75.8ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 480)
# 6.911 1.1679683292363678 -1.7980380562246712
#
# 0: 480x480 (no detections), 78.0ms
# Speed: 2.3ms preprocess, 78.0ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 480)
# 6.919 1.1693203400356578 -1.800119419912965
#
# 0: 480x480 (no detections), 81.8ms
# Speed: 3.0ms preprocess, 81.8ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 480)
# 6.907 1.1672923238367232 -1.7969973743805245
#
# 0: 480x480 (no detections), 80.5ms
# Speed: 9.6ms preprocess, 80.5ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 480)
# 6.915 1.1686443346360127 -1.7990787380688182
#
# 0: 480x480 (no detections), 83.6ms
# Speed: 2.9ms preprocess, 83.6ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 480)
# 6.91 1.167799327886457 -1.7977778857636348
#
# 0: 480x480 (no detections), 146.9ms
# Speed: 8.6ms preprocess, 146.9ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 480)
# 6.922 1.1698273440853912 -1.8008999312960752
#
# 0: 480x480 (no detections), 88.8ms
# Speed: 2.3ms preprocess, 88.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 480)
# 6.906 1.167123322486812 -1.7967372039194878
#
# 0: 480x480 (no detections), 78.6ms
# Speed: 2.5ms preprocess, 78.6ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 480)
# 6.905 1.166954321136901 -1.7964770334584512
#
# 0: 480x480 (no detections), 87.3ms
# Speed: 2.5ms preprocess, 87.3ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 480)
# 6.904 1.1667853197869895 -1.7962168629974145
#
# 0: 480x480 (no detections), 74.8ms
# Speed: 2.2ms preprocess, 74.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 480)
# 6.908 1.1674613251866346 -1.7972575448415615
#
# 0: 480x480 (no detections), 77.9ms
# Speed: 2.5ms preprocess, 77.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 480)
# 6.913 1.1683063319361904 -1.798558397146745
#
# 0: 480x480 (no detections), 79.5ms
# Speed: 2.5ms preprocess, 79.5ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 480)
# 6.924 1.1701653467852138 -1.8014202722181487
#
# 0: 480x480 (no detections), 82.9ms
# Speed: 2.6ms preprocess, 82.9ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 480)
# 6.903 1.1666163184370781 -1.7959566925363777
#
# 0: 480x480 (no detections), 79.1ms
# Speed: 2.3ms preprocess, 79.1ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 480)
# 6.906 1.167123322486812 -1.7967372039194878
#
# 0: 480x480 (no detections), 76.9ms
# Speed: 2.6ms preprocess, 76.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 480)
# 6.91 1.167799327886457 -1.7977778857636348
#
# 0: 480x480 (no detections), 80.2ms
# Speed: 2.8ms preprocess, 80.2ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 480)
# 6.914 1.1684753332861015 -1.7988185676077815
#
# 0: 480x480 (no detections), 79.8ms
# Speed: 2.6ms preprocess, 79.8ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 480)
# 6.919 1.1693203400356578 -1.800119419912965
#
# 0: 480x480 (no detections), 79.7ms
# Speed: 2.7ms preprocess, 79.7ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 480)
# 6.916 1.168813335985924 -1.799338908529855
#
# 0: 480x480 (no detections), 79.0ms
# Speed: 2.3ms preprocess, 79.0ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 480)
# 6.913 1.1683063319361904 -1.798558397146745
#
# 0: 480x480 (no detections), 80.1ms
# Speed: 2.3ms preprocess, 80.1ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 480)
# 6.916 1.168813335985924 -1.799338908529855
#
# 0: 480x480 (no detections), 80.4ms
# Speed: 2.3ms preprocess, 80.4ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 480)
# 6.906 1.167123322486812 -1.7967372039194878
#
# 0: 480x480 (no detections), 78.9ms
# Speed: 2.4ms preprocess, 78.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 480)
# 6.913 1.1683063319361904 -1.798558397146745
#
# 0: 480x480 (no detections), 83.5ms
# Speed: 1.9ms preprocess, 83.5ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 480)
# 6.903 1.1666163184370781 -1.7959566925363777
#
# 0: 480x480 1 person, 83.9ms
# Speed: 2.4ms preprocess, 83.9ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 480)
# 2.51 0.4241933882771355 -0.6530278572021306
#
# 0: 480x480 1 person, 81.7ms
# Speed: 2.5ms preprocess, 81.7ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 480)
# 2.386 0.40323722088814556 -0.6207667200335792
#
# 0: 480x480 1 person, 90.1ms
# Speed: 2.3ms preprocess, 90.1ms inference, 4.9ms postprocess per image at shape (1, 3, 480, 480)
# 2.283 0.385830081847291 -0.5939691625467985
#
# 0: 480x480 1 person, 92.1ms
# Speed: 3.1ms preprocess, 92.1ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 480)
# detedted
# 2.212 0.33194090796657033 -0.5927386156495567
#
# 0: 480x480 1 person, 79.2ms
# Speed: 2.4ms preprocess, 79.2ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 480)
# detedted
# 2.143 0.31203748189545644 -0.5623177927261919
#
# 0: 480x480 1 person, 71.1ms
# Speed: 2.2ms preprocess, 71.1ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 480)
# detedted
# 2.122 0.2924326697278434 -0.5473559909258351
#
# 0: 480x480 1 person, 79.0ms
# Speed: 2.1ms preprocess, 79.0ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 480)
# detedted
# 2.101 0.27549583801174277 -0.5349207384791796
#
# 0: 480x480 1 person, 80.1ms
# Speed: 2.7ms preprocess, 80.1ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 480)
# detedted
# 2.092 0.2673243693717154 -0.5279703952619914
#
# 0: 480x480 1 person, 78.0ms
# Speed: 2.8ms preprocess, 78.0ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 480)
# detedted
# 2.079 0.2587152869047462 -0.5200595427671908
#
# 0: 480x480 1 person, 88.9ms
# Speed: 2.7ms preprocess, 88.9ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 480)
# detedted
# 2.08 0.25188849817720516 -0.5179935952908622
#
# 0: 480x480 1 person, 81.0ms
# Speed: 2.3ms preprocess, 81.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 480)
# detedted
# 2.071 0.24157039140353917 -0.5180583516454315
#
# 0: 480x480 1 person, 80.1ms
# Speed: 2.0ms preprocess, 80.1ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 480)
# detedted
# 2.075 0.23741395454904576 -0.5190589472063112
#
# 0: 480x480 1 person, 77.6ms
# Speed: 3.0ms preprocess, 77.6ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 480)
# detedted
# 2.075 0.23279094040550644 -0.5167484183791052
#
# 0: 480x480 1 person, 78.7ms
# Speed: 2.3ms preprocess, 78.7ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 480)
# detedted
# 2.073 0.23025728448233074 -0.5162503476144025
#
# 0: 480x480 1 person, 79.0ms
# Speed: 3.3ms preprocess, 79.0ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 480)
# detedted
# 2.076 0.23290312881052114 -0.5169974537614567
#
# 0: 480x480 1 person, 78.2ms
# Speed: 2.6ms preprocess, 78.2ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 480)
# detedted
# 2.072 0.2324543751904623 -0.5160013122320511
#
# 0: 480x480 1 person, 80.8ms
# Speed: 4.8ms preprocess, 80.8ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 480)
# detedted
# 2.077 0.2330153172155358 -0.5149337333008651
#
# 0: 480x480 1 person, 75.5ms
# Speed: 2.3ms preprocess, 75.5ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 480)
# detedted
# 2.08 0.23566895939890808 -0.5179935952908622
#
# 0: 480x480 1 person, 79.9ms
# Speed: 2.3ms preprocess, 79.9ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 480)
# detedted
# 2.092 0.23702858801082488 -0.5233114783400495
#
# 0: 480x480 1 person, 73.4ms
# Speed: 2.2ms preprocess, 73.4ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 480)
# detedted
# 2.078 0.24238690165936952 -0.5198093938769708
#
# 0: 480x480 1 person, 70.0ms
# Speed: 2.3ms preprocess, 70.0ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 480)
# detedted
# 2.063 0.2452335154655059 -0.5137599937908888
#
# 0: 480x480 1 person, 72.9ms
# Speed: 2.3ms preprocess, 72.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 480)
# detedted
# 2.069 0.25286121873851364 -0.5129503583050024
#
# 0: 480x480 1 person, 105.4ms
# Speed: 9.6ms preprocess, 105.4ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 480)
# detedted
# 2.07 0.27143093035902305 -0.5131982801794851
#
# 0: 480x480 1 person, 78.7ms
# Speed: 2.4ms preprocess, 78.7ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 480)
# detedted
# 2.148 0.28644441764052603 -0.5157934820778857
#
# 0: 480x480 1 person, 77.7ms
# Speed: 1.7ms preprocess, 77.7ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 480)
# detedted
# 2.22 0.30099197464391625 -0.4861148871801902
#
# 0: 480x480 2 persons, 78.7ms
# Speed: 1.8ms preprocess, 78.7ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 480)
# detedted
# 2.294 0.32380238317053583 -0.4537853627949863
#
# 0: 480x480 1 person, 81.1ms
# Speed: 2.5ms preprocess, 81.1ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 480)
# detedted
# 2.328 0.4064018617814395 -0.40866611312965373
#
# 0: 480x480 1 person, 75.2ms
# Speed: 2.2ms preprocess, 75.2ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 480)
# detedted
# 2.395 0.44744592026154584 -0.3724242277400881
#
# 0: 480x480 1 person, 75.4ms
# Speed: 2.6ms preprocess, 75.4ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 480)
# detedted
# 2.449 0.47117514795377685 -0.3426435359148764
#
# 0: 480x480 1 person, 79.5ms
# Speed: 2.5ms preprocess, 79.5ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 480)
# detedted
# 2.485 0.483637842089353 -0.32000968338629815
#
# 0: 480x480 1 person, 76.5ms
# Speed: 2.2ms preprocess, 76.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 480)
# detedted
# 2.521 0.49906929109059955 -0.3106098718752338
#
# 0: 480x480 1 person, 76.2ms
# Speed: 2.2ms preprocess, 76.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 480)
# detedted
# 2.559 0.5179946461817041 -0.30959288034595406
#
# 0: 480x480 1 person, 81.3ms
# Speed: 4.5ms preprocess, 81.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 480)
# detedted
# 2.577 0.527379668680904 -0.31464006571762504
#
# 0: 480x480 1 person, 77.5ms
# Speed: 2.5ms preprocess, 77.5ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 480)
# detedted
# 2.593 0.5306540476870719 -0.31948091938614886
#
# 0: 480x480 1 person, 84.9ms
# Speed: 3.2ms preprocess, 84.9ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 480)
# detedted
# 2.601 0.5322912371901558 -0.32625905926391446
#
# 0: 480x480 1 person, 76.7ms
# Speed: 2.0ms preprocess, 76.7ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 480)
# detedted
# 2.619 0.5301398899374298 -0.334349461640286
#
# 0: 480x480 1 person, 77.0ms
# Speed: 2.7ms preprocess, 77.0ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 480)
# detedted
# 2.62 0.5303423106666919 -0.3432292965116362
#
# 0: 480x480 1 person, 75.7ms
# Speed: 3.3ms preprocess, 75.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 480)
# detedted
# 2.627 0.5317592557715265 -0.3470715065202804
#
# 0: 480x480 1 person, 81.0ms
# Speed: 5.3ms preprocess, 81.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 480)
# detedted
# 2.629 0.5321640972300508 -0.35026315281896436
#
# 0: 480x480 1 person, 75.5ms
# Speed: 2.9ms preprocess, 75.5ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 480)
# detedted
# 2.642 0.534795566710458 -0.3549370379399398
#
# 0: 480x480 1 person, 77.0ms
# Speed: 2.5ms preprocess, 77.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 480)
# detedted
# 2.647 0.5387563735948283 -0.35855621362740886
#
# 0: 480x480 1 person, 90.4ms
# Speed: 4.1ms preprocess, 90.4ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 480)
# detedted
# 2.653 0.5429329689602013 -0.36232309548119285
#
# 0: 480x480 1 person, 74.9ms
# Speed: 2.5ms preprocess, 74.9ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 480)
# detedted
# 2.649 0.5391634430119759 -0.36177681113067467
#
# 0: 480x480 1 person, 77.7ms
# Speed: 1.8ms preprocess, 77.7ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 480)
# detedted
# 2.659 0.5441608610875142 -0.36610333942939927
#
# 0: 480x480 1 person, 78.6ms
# Speed: 3.2ms preprocess, 78.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 480)
# detedted
# 2.642 0.5436249667349623 -0.36082081351726786
#
# 0: 480x480 1 person, 78.1ms
# Speed: 1.8ms preprocess, 78.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 480)
# detedted
# 2.633 0.5447062102578838 -0.3595916737286019
#
# 0: 480x480 1 person, 78.8ms
# Speed: 2.9ms preprocess, 78.8ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 480)
# detedted
# 2.629 0.5468073552822976 -0.35904538937808367
#
# 0: 480x480 1 person, 76.9ms
# Speed: 4.5ms preprocess, 76.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 480)
# detedted
# 2.64 0.5579179683149581 -0.36054767134200877
#
# 0: 480x480 1 person, 78.3ms
# Speed: 4.2ms preprocess, 78.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 480)
# detedted
# 2.647 0.5682434059754274 -0.36445112428342225
#
# 0: 480x480 1 person, 80.6ms
# Speed: 3.1ms preprocess, 80.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 480)
# detedted
# 2.644 0.5823261889709793 -0.36698218530132914
#
# 0: 480x480 1 person, 82.2ms
# Speed: 2.4ms preprocess, 82.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 480)
# detedted
# 2.636 0.6128651779069292 -0.3688070072158491
#
# 0: 480x480 1 person, 75.4ms
# Speed: 3.6ms preprocess, 75.4ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 480)
# detedted
# 2.638 0.6544716581878499 -0.3778991317098891
#
# 0: 480x480 1 person, 75.8ms
# Speed: 2.3ms preprocess, 75.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 480)
# detedted
# 2.63 0.7052226877552161 -0.37968164032540475
#
# 0: 480x480 1 person, 74.1ms
# Speed: 4.0ms preprocess, 74.1ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 480)
# detedted
# 2.622 0.7644154525466162 -0.3726874799211437
#
# 0: 480x480 1 person, 79.2ms
# Speed: 2.8ms preprocess, 79.2ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 480)
# detedted
# 2.574 0.8077692319512437 -0.3343369640368357
#
# 0: 480x480 1 person, 76.4ms
# Speed: 2.3ms preprocess, 76.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 480)
# detedted
# 2.633 0.8732142533598538 -0.2657719547574902
#
# 0: 480x480 1 person, 75.7ms
# Speed: 3.1ms preprocess, 75.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 480)
# detedted
# 2.673 0.862658612935296 -0.21028137753917886
#
# 0: 480x480 1 person, 79.8ms
# Speed: 2.5ms preprocess, 79.8ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 480)
# detedted
# 2.728 0.8560973056577286 -0.1690434128744318
#
# 0: 480x480 1 person, 76.1ms
# Speed: 2.6ms preprocess, 76.1ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 480)
# detedted
# 2.768 0.8563160731358965 -0.1376179677108544
#
# 0: 480x480 1 person, 84.6ms
# Speed: 2.2ms preprocess, 84.6ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 480)
# detedted
# 2.736 0.8311772283699745 -0.10556143326350576
#
# 0: 480x480 1 person, 76.2ms
# Speed: 1.8ms preprocess, 76.2ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 480)
# detedted
# 2.69 0.7962265269859177 -0.08281928991989254
#
# 0: 480x480 1 person, 76.4ms
# Speed: 3.7ms preprocess, 76.4ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 480)
# detedted
# 0.0 0.0 0.0
#
# 0: 480x480 1 person, 75.7ms
# Speed: 2.7ms preprocess, 75.7ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 480)
# detedted
# 0.0 0.0 0.0
#
# 0: 480x480 1 person, 88.7ms
# Speed: 2.4ms preprocess, 88.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 480)
# detedted
# 0.0 0.0 0.0
#
# 0: 480x480 1 person, 78.0ms
# Speed: 2.2ms preprocess, 78.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 480)
# detedted
# 0.0 0.0 0.0
#
# 0: 480x480 1 person, 87.2ms
# Speed: 3.3ms preprocess, 87.2ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 480)
# detedted
# 3.091 -0.21792848870185375 -0.14679300613210905
#
# 0: 480x480 1 person, 77.3ms
# Speed: 2.5ms preprocess, 77.3ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 480)
# detedted
# 3.064 -0.3969262036300332 -0.15574612808969718
#
# 0: 480x480 1 person, 77.1ms
# Speed: 2.4ms preprocess, 77.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 480)
# detedted
# 3.067 -0.48272920267121144 -0.15931374966774528
#
# 0: 480x480 1 person, 75.5ms
# Speed: 2.4ms preprocess, 75.5ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 480)
# detedted
# 3.07 -0.527660300766255 -0.15605111398021226
#
# 0: 480x480 1 person, 80.7ms
# Speed: 2.9ms preprocess, 80.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 480)
# detedted
# 3.056 -0.5320626738467927 -0.15874236028191377
#
# 0: 480x480 1 person, 76.7ms
# Speed: 2.3ms preprocess, 76.7ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 480)
# detedted
# 3.019 -0.5424363332674719 -0.15009705365573317
#
# 0: 480x480 1 person, 73.7ms
# Speed: 3.6ms preprocess, 73.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 480)
# detedted
# 3.006 -0.5401005689970256 -0.14610352184243144
#
# 0: 480x480 1 person, 79.9ms
# Speed: 1.7ms preprocess, 79.9ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 480)
# detedted
# 2.997 -0.548499289416639 -0.1423289030662992
#
# 0: 480x480 1 person, 82.2ms
# Speed: 2.4ms preprocess, 82.2ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 480)
# detedted
# 3.0 -0.5557322136245707 -0.14247137444073993
#
# 0: 480x480 1 person, 78.1ms
# Speed: 4.0ms preprocess, 78.1ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 480)
# detedted
# 3.005 -0.563353449643906 -0.14605491787641597
#
# 0: 480x480 1 person, 77.3ms
# Speed: 3.0ms preprocess, 77.3ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 480)
# detedted
# 3.037 -0.5795020201073809 -0.16113713837584845
#
# 0: 480x480 1 person, 78.9ms
# Speed: 3.4ms preprocess, 78.9ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 480)
# detedted
# 3.049 -0.5953778794060282 -0.17195909081919425
#
# 0: 480x480 1 person, 79.5ms
# Speed: 2.4ms preprocess, 79.5ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 480)
# detedted
# 3.052 -0.6197627430761468 -0.18572199044152993
#
# 0: 480x480 1 person, 77.1ms
# Speed: 2.5ms preprocess, 77.1ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 480)
# detedted
# 3.042 -0.6414531411374528 -0.19188804678799126
#
# 0: 480x480 1 person, 154.9ms
# Speed: 2.4ms preprocess, 154.9ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 480)
# detedted
# 3.01 -0.6313523643571767 -0.19657281797075557
#
# 0: 480x480 1 person, 78.5ms
# Speed: 2.1ms preprocess, 78.5ms inference, 3.3ms postprocess per image at shape (1, 3, 480, 480)
# detedted
# 3.007 -0.4933839421078877 -0.17293867109387537
#
# 0: 480x480 1 person, 77.6ms
# Speed: 2.3ms preprocess, 77.6ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 480)
# detedted
# 3.047 -0.3166551526914526 -0.1379177090228051
#
# 0: 480x480 1 person, 75.6ms
# Speed: 2.0ms preprocess, 75.6ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 480)
# detedted
# 2.978 -0.07062943747444354 -0.08505413500915905
#
# 0: 480x480 1 person, 75.4ms
# Speed: 1.8ms preprocess, 75.4ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 480)
# detedted
# 2.887 0.18881347781703026 -0.024590550094227476
#
# 0: 480x480 1 person, 75.6ms
# Speed: 2.1ms preprocess, 75.6ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 480)
# detedted
# 2.816 0.39434669206481476 0.02932005406330806
#
# 0: 480x480 1 person, 78.5ms
# Speed: 2.8ms preprocess, 78.5ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 480)
# detedted
# 2.792 0.5558279853850048 0.057050392959400655
#
# 0: 480x480 1 person, 77.2ms
# Speed: 2.7ms preprocess, 77.2ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 480)
# detedted
# 2.749 0.6881347372391781 0.07147691717354134
#
# 0: 480x480 1 person, 76.6ms
# Speed: 2.1ms preprocess, 76.6ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 480)
# detedted
# 2.729 0.7287290435701623 0.07399565892324252
#
# 0: 480x480 1 person, 77.3ms
# Speed: 2.5ms preprocess, 77.3ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 480)
# detedted
# 2.612 0.700396068599477 0.07082325434500163
#
# 0: 480x480 1 person, 80.8ms
# Speed: 2.7ms preprocess, 80.8ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 480)
# detedted
# 2.639 0.710575788736652 0.07155534770921106
#
# 0: 480x480 1 person, 94.1ms
# Speed: 2.7ms preprocess, 94.1ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 480)
# detedted
# 2.627 0.6927125566219556 0.07122997288067354
#
# 0: 480x480 1 person, 79.6ms
# Speed: 5.2ms preprocess, 79.6ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 480)
# detedted
# 2.613 0.6773775905764312 0.06794077285356984
#
# 0: 480x480 1 person, 77.9ms
# Speed: 2.7ms preprocess, 77.9ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 480)
# detedted
# 2.592 0.6603839459154341 0.06739475056886837
#
# 0: 480x480 1 person, 77.2ms
# Speed: 2.5ms preprocess, 77.2ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 480)
# detedted
# 2.587 0.6504644636928006 0.06726474526298706
#
# 0: 480x480 1 person, 83.8ms
# Speed: 2.6ms preprocess, 83.8ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 480)
# detedted
# 2.585 0.6413226824926429 0.06721274314063454
#
# 0: 480x480 1 person, 80.9ms
# Speed: 1.6ms preprocess, 80.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 480)
# detedted
# 2.584 0.6439531111530243 0.06718674207945828
#
# 0: 480x480 1 person, 90.2ms
# Speed: 3.1ms preprocess, 90.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 480)
# detedted
# 2.592 0.6430593396599344 0.06739475056886837
#
# 0: 480x480 1 person, 133.3ms
# Speed: 8.0ms preprocess, 133.3ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 480)
# detedted
# 2.6 0.6421477444978574 0.06760275905827845
#
# 0: 480x480 1 person, 80.1ms
# Speed: 2.9ms preprocess, 80.1ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 480)
# detedted
# 2.603 0.6428886842030472 0.06768076224180723
#
# 0: 480x480 1 person, 93.4ms
# Speed: 2.3ms preprocess, 93.4ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 480)
# detedted
# 2.602 0.6397431301322836 0.06765476118063098
#
# 0: 480x480 1 person, 83.4ms
# Speed: 2.6ms preprocess, 83.4ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 480)
# detedted
# 2.599 0.6361103001339304 0.06468275104678507
#
# 0: 480x480 1 person, 77.7ms
# Speed: 1.8ms preprocess, 77.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 480)
# detedted
# 2.589 0.6336627807028649 0.06443387551370779
#
# 0: 480x480 1 person, 77.5ms
# Speed: 2.5ms preprocess, 77.5ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 480)
# detedted
# 2.587 0.6302914123372938 0.06438410040709233
#
# 0: 480x480 1 person, 82.1ms
# Speed: 2.0ms preprocess, 82.1ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 480)
# detedted
# 2.587 0.6274095478579357 0.06438410040709233
#
# 0: 480x480 1 person, 78.5ms
# Speed: 1.9ms preprocess, 78.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 480)
# detedted
# 2.577 0.624984308013104 0.06413522487401505
#
# 0: 480x480 1 person, 146.9ms
# Speed: 2.0ms preprocess, 146.9ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 480)
# detedted
# 2.571 0.620665123295834 0.0639858995541687
#
# 0: 480x480 1 person, 90.3ms
# Speed: 2.4ms preprocess, 90.3ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 480)
# detedted
# 2.57 0.6146978596285438 0.06396101200086095
#
# 0: 480x480 1 person, 78.1ms
# Speed: 1.7ms preprocess, 78.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 480)
# detedted
# 2.569 0.6087350518785006 0.06393612444755323
#
# 0: 480x480 1 person, 82.3ms
# Speed: 2.4ms preprocess, 82.3ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 480)
# detedted
# 2.566 0.6080241896147266 0.06386146178763004
#
# 0: 480x480 1 person, 81.9ms
# Speed: 2.5ms preprocess, 81.9ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 480)
# detedted
# 2.569 0.605873239026753 0.061075522733292094
#
# 0: 480x480 1 person, 94.5ms
# Speed: 2.4ms preprocess, 94.5ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 480)
# detedted
# 2.574 0.6070524395698179 0.061194392960488064
#
# 0: 480x480 1 person, 83.0ms
# Speed: 3.4ms preprocess, 83.0ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 480)
# detedted
# 2.585 0.6096466807645607 0.06145590746031922
#
# 0: 480x480 1 person, 78.0ms
# Speed: 2.6ms preprocess, 78.0ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 480)
# detedted
# 2.582 0.6089391604387218 0.06138458532400163
#
# 0: 480x480 1 person, 87.5ms
# Speed: 2.5ms preprocess, 87.5ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 480)
# detedted
# 2.589 0.6134741336369942 0.061551003642075997
#
# 0: 480x480 1 person, 82.6ms
# Speed: 2.6ms preprocess, 82.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 480)
# detedted
# 2.591 0.6139480418128436 0.06159855173295439
#
# 0: 480x480 1 person, 80.4ms
# Speed: 2.3ms preprocess, 80.4ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 480)
# detedted
# 2.58 0.6113415468456722 0.06133703723312325
#
# 0: 480x480 1 person, 81.5ms
# Speed: 2.3ms preprocess, 81.5ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 480)
# detedted
# 2.587 0.6101183609817867 0.061503455551197614
#
# 0: 480x480 1 person, 81.3ms
# Speed: 2.4ms preprocess, 81.3ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 480)
# detedted
# 2.572 0.606580759352592 0.06114684486960968
#
# 0: 480x480 1 person, 86.1ms
# Speed: 2.5ms preprocess, 86.1ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 480)
# detedted
# 2.562 0.6070763732630279 0.06090910441521773
#
# 0: 480x480 1 person, 81.6ms
# Speed: 2.7ms preprocess, 81.6ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 480)
# detedted
# 2.559 0.6092161840578846 0.060837782278900146
#
# 0: 480x480 1 person, 82.4ms
# Speed: 3.4ms preprocess, 82.4ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 480)
# detedted
# 2.557 0.611588493023419 0.060790234188021756
#
# 0: 480x480 1 person, 74.4ms
# Speed: 2.6ms preprocess, 74.4ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 480)
# detedted
# 2.553 0.6106317648372267 0.06069513800626498
#
# 0: 480x480 1 person, 74.6ms
# Speed: 3.2ms preprocess, 74.6ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 480)
# detedted
# 2.544 0.6084791264182942 0.06048117159731222
#
# 0: 480x480 1 person, 82.1ms
# Speed: 2.5ms preprocess, 82.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 480)
# detedted
# 2.551 0.6129951619682678 0.060647589915386595
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 170
#     166 frames = pipeline.wait_for_frames()
#     167 # frames.get_depth_frame() is a 640x360 depth image
#     168
#     169 # Align the depth frame to color frame
# --> 170 aligned_frames = align.process(frames)
#     172 # Get aligned frames
#     173 aligned_depth_frame = aligned_frames.get_depth_frame() # aligned_depth_frame is a 640x480 depth image
#
# KeyboardInterrupt:
# 在当前单元格或上一个单元格中执行代码时 Kernel 崩溃。
#
# 请查看单元格中的代码，以确定故障的可能原因。
#
# 单击<a href='https://aka.ms/vscodeJupyterKernelCrash'>此处</a>了解详细信息。
#
# 有关更多详细信息，请查看 Jupyter <a href='command:jupyter.viewOutput'>log</a>。
